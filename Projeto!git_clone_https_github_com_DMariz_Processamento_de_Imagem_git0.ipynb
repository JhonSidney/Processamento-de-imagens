# %% [markdown]
# <a href="https://colab.research.google.com/github/JhonSidney/Processamento-de-imagens/blob/master/Projeto!git_clone_https_github_com_DMariz_Processamento_de_Imagem_git0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DMariz/Processamento_de_Imagem.git
# Out:
# Cloning into 'Processamento_de_Imagem'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 119 (delta 0), reused 0 (delta 0), pack-reused 116
# Receiving objects: 100% (119/119), 2.87 MiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
import cv2
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow  #usar o comando imshow diretamente no colab

# %% [markdown]
# # PRÉ - PROCESSAMENTO
#
# O objetivo e utilizar o aprimoramento de imagem é para transformar a imagem mais adequada
# a outros processamentos de imagens, como melhor visualização de características ou restaurar imagens que foram deterioradas. A finalidade da manipulação de contraste é melhorar a visualização de contraste geral da imagem, destacar as regiões de baixa intensidade, melhorando a leitura
# da imagem.

# %% [markdown]
# ## Equalização do Histograma (HE)
#
# Na equalização do histograma (HE) os valores de intensidade da imagem são
# redistribuídos para aperfeiçoar o contraste. HE remapeia os tons de cinza de uma imagem baseada na probabilidade de distribuição dos nos níveis de cinza dados

# %%
img = cv2.imread('Processamento_de_Imagem/media/media/mdb001.jpeg') #Lendo uma imagem
print(img.shape)

plt.figure(figsize=(7, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #Conversão necessária para protar a imagem, devido ao opencv usa o 
                                                 #formato RGB, enquanto o matplotlib usa RGB

imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

equ = cv2.equalizeHist(imggray)

fig, axes = plt.subplots(1, 2, figsize=(20, 10))
ax = axes.ravel()

ax[0].imshow(imggray, cmap='gray')
ax[0].set_title('Imagem de entrada')
ax[0].set_axis_off()

ax[1].imshow(equ, cmap='gray')
ax[1].set_title('Equalizada')
ax[1].set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0070ae202d4f> in <module>()
#       1 img = cv2.imread('Processamento_de_Imagem/media/media/mdb001.jpeg') #Lendo uma imagem
# ----> 2 print(img.shape)
#       3
#       4 plt.figure(figsize=(7, 6), dpi= 80, facecolor='w', edgecolor='k')
#       5 plt.axis("off")
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ## Testando Histograma

# %%
gaivota = cv2.imread('Processamento_de_Imagem/media/paisagem.jpeg')

print(gaivota.shape)

plt.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k')
plt.axis("off")
plt.imshow(cv2.cvtColor(gaivota, cv2.COLOR_BGR2RGB)) #Conversão necessária para protar a imagem, devido ao opencv usa o 
                                                 #formato RGB, enquanto o matplotlib usa RGB
# Out:
# (660, 990, 3)

# %%
plt.hist(gaivota.ravel(),256,[0,256]); 
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([gaivota],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()
